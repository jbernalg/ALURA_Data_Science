# %% [markdown]
# # __Pandas: Leyendo Diferentes Tipos de Archivos__

# %% [markdown]
# ## Importar archivos csv

# %%
import pandas as pd

# %%
# leer csv
df = pd.read_csv('./superstore_data.csv')
df.head()
# Out:
#       Id  Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 0   1826        1970  Graduation       Divorced  84835.0        0         0
# 1      1        1961  Graduation         Single  57091.0        0         0
# 2  10476        1958  Graduation        Married  67267.0        0         1
# 3   1386        1967  Graduation       Together  32474.0        1         1
# 4   5371        1989  Graduation         Single  21474.0        1         0
#
#   Dt_Customer  Recency  MntWines  ...  MntFishProducts  MntSweetProducts  \
# 0   6/16/2014        0       189  ...              111               189
# 1   6/15/2014        0       464  ...                7                 0
# 2   5/13/2014        0       134  ...               15                 2
# 3   11/5/2014        0        10  ...                0                 0
# 4    8/4/2014        0         6  ...               11                 0
#
# ...

# %% [markdown]
# ## Parametros de la funcion _read_csv_

# %% [markdown]
# Documentacion: https://pandas.pydata.org/docs/reference/api/pandas.read_csv.html

# %% [markdown]
# Ahora, importemos archivo separado por punto y coma utilizando el parametro _sep_

# %%
df_punto_coma = pd.read_csv('./superstore_data_punto_coma.csv', sep=';')
df_punto_coma.head()
# Out:
#       Id  Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 0   1826        1970  Graduation       Divorced  84835.0        0         0
# 1      1        1961  Graduation         Single  57091.0        0         0
# 2  10476        1958  Graduation        Married  67267.0        0         1
# 3   1386        1967  Graduation       Together  32474.0        1         1
# 4   5371        1989  Graduation         Single  21474.0        1         0
#
#   Dt_Customer  Recency  MntWines  ...  MntFishProducts  MntSweetProducts  \
# 0   6/16/2014        0       189  ...              111               189
# 1   6/15/2014        0       464  ...                7                 0
# 2   5/13/2014        0       134  ...               15                 2
# 3   11/5/2014        0        10  ...                0                 0
# 4    8/4/2014        0         6  ...               11                 0
#
# ...

# %% [markdown]
# Carguemos nuevamente el archivo separado por coma y leamos solo 5 registros con _nrows_

# %%
df_5_rows = pd.read_csv('./superstore_data.csv', nrows=5)
df_5_rows
# Out:
#       Id  Year_Birth   Education Marital_Status  Income  Kidhome  Teenhome  \
# 0   1826        1970  Graduation       Divorced   84835        0         0
# 1      1        1961  Graduation         Single   57091        0         0
# 2  10476        1958  Graduation        Married   67267        0         1
# 3   1386        1967  Graduation       Together   32474        1         1
# 4   5371        1989  Graduation         Single   21474        1         0
#
#   Dt_Customer  Recency  MntWines  ...  MntFishProducts  MntSweetProducts  \
# 0   6/16/2014        0       189  ...              111               189
# 1   6/15/2014        0       464  ...                7                 0
# 2   5/13/2014        0       134  ...               15                 2
# 3   11/5/2014        0        10  ...                0                 0
# 4    8/4/2014        0         6  ...               11                 0
#
#    MntGoldProds  NumDealsPurchases  NumWebPurchases  NumCatalogPurchases  \
# ...

# %% [markdown]
# Carguemos nuevamente el archivo separado por coma y leamos solo algunas columnas con _usecols_

# %%
df_seleccion = pd.read_csv('./superstore_data.csv', usecols=['Id', 'Year_Birth', 'Income'])
df_seleccion.head()
# Out:
#       Id  Year_Birth   Income
# 0   1826        1970  84835.0
# 1      1        1961  57091.0
# 2  10476        1958  67267.0
# 3   1386        1967  32474.0
# 4   5371        1989  21474.0

# %%
# seleccion de columnas por su posicion
df_seleccion = pd.read_csv('./superstore_data.csv', usecols=[0, 1, 4])
df_seleccion.head()
# Out:
#       Id  Year_Birth   Income
# 0   1826        1970  84835.0
# 1      1        1961  57091.0
# 2  10476        1958  67267.0
# 3   1386        1967  32474.0
# 4   5371        1989  21474.0

# %% [markdown]
# ## Exportar archivos csv

# %% [markdown]
# Documentacion: https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.to_csv.html
#
# Vamos a exportar el archivo _df_seleccion_ pero sin importar lo indices usando el parametro _index_.

# %%
df_seleccion.to_csv('clientes_mercado.csv', index=False)

# %% [markdown]
# Ahora, importamos el archivo que acabamos de exportar

# %%
clientes_mercado = pd.read_csv('clientes_mercado.csv')
clientes_mercado
# Out:
#          Id  Year_Birth   Income
# 0      1826        1970  84835.0
# 1         1        1961  57091.0
# 2     10476        1958  67267.0
# 3      1386        1967  32474.0
# 4      5371        1989  21474.0
# ...     ...         ...      ...
# 2235  10142        1976  66476.0
# 2236   5263        1977  31056.0
# 2237     22        1976  46310.0
# 2238    528        1978  65819.0
# 2239   4070        1969  94871.0
#
# [2240 rows x 3 columns]

# %% [markdown]
# ## Importar archivos Excel

# %%
import pandas as pd

archivo = 'emisiones_CO2.xlsx'
df = pd.read_excel(archivo)
df
# Out:
#              País ISO 3166-1 alpha-3   Año         Total        Carbón  \
# 0      Afganistán                AFG  1750  0.000000e+00           NaN
# 1      Afganistán                AFG  1751  0.000000e+00           NaN
# 2      Afganistán                AFG  1752  0.000000e+00           NaN
# 3      Afganistán                AFG  1753  0.000000e+00           NaN
# 4      Afganistán                AFG  1754  0.000000e+00           NaN
# ...           ...                ...   ...           ...           ...
# 63099      Global                WLD  2017  3.609674e+10  1.450697e+10
# 63100      Global                WLD  2018  3.682651e+10  1.474683e+10
# 63101      Global                WLD  2019  3.708256e+10  1.472598e+10
# 63102      Global                WLD  2020  3.526409e+10  1.417456e+10
# 63103      Global                WLD  2021  3.712385e+10  1.497960e+10
#
#              Aceite           Gas       Cemento        Quema        Otros  \
# ...

# %% [markdown]
# Obtener el nombre de las hojas del archivo excel.

# %%
pd.ExcelFile(archivo).sheet_names
# Out:
# ['emisiones_C02', 'emisiones_percapita', 'fuentes']

# %% [markdown]
# ## Parametros de la funcion _read_excel_

# %% [markdown]
# Documentacion: https://pandas.pydata.org/docs/reference/api/pandas.read_excel.html
#
# Vamos a abrir una hoja epecifica del archivo de excel con el parametro _sheet_name_. Por defecto, muestra la hoja con indice 0.

# %%
# cargar hoja percapita
percapita = pd.read_excel(archivo, sheet_name='emisiones_percapita')
percapita.tail()
# Out:
#          País ISO 3166-1 alpha-3   Año      Total     Carbón     Aceite  \
# 63099  Global                WLD  2017  4749682.0  1908857.0  1610910.0
# 63100  Global                WLD  2018  4792753.0  1919213.0  1596350.0
# 63101  Global                WLD  2019  4775633.0  1896468.0  1589920.0
# 63102  Global                WLD  2020  4497423.0  1807760.0  1427353.0
# 63103  Global                WLD  2021  4693699.0  1893923.0  1496614.0
#
#              Gas   Cemento    Quema    Otros
# 63099   940144.0  198416.0  51579.0  39776.0
# 63100   979965.0  204225.0  53634.0  39366.0
# 63101   984878.0  208309.0  56569.0  39490.0
# 63102   963695.0  208844.0  51981.0  37789.0
# 63103  1001585.0  211472.0  52663.0  37443.0

# %%
# cargar hoja fuentes
fuentes = pd.read_excel(archivo, sheet_name='fuentes')
fuentes.sample(5)
# Out:
#                   País ISO 3166-1 alpha-3   Año       Total      Carbón  \
# 33199       Madagascar                MDG  1765      [NONE]      [NONE]
# 10905  Isla De Navidad                CXR  1775      [NONE]      [NONE]
# 13399          Curazao                CUW  1821      [NONE]      [NONE]
# 8644      Burkina Faso                BFA  1962  CDIAC 2022  CDIAC 2022
# 27458          Jamaica                JAM  2008  CDIAC 2022  CDIAC 2022
#
#            Aceite         Gas        Cemento       Quema   Otros  \
# 33199      [NONE]      [NONE]         [NONE]      [NONE]  [NONE]
# 10905      [NONE]      [NONE]         [NONE]      [NONE]  [NONE]
# 13399      [NONE]      [NONE]         [NONE]      [NONE]  [NONE]
# 8644   CDIAC 2022  CDIAC 2022  Andrew cement  CDIAC 2022  [NONE]
# 27458  CDIAC 2022  CDIAC 2022  Andrew cement  CDIAC 2022  [NONE]
#
#                          Per Capita
# 33199                        [NONE]
# 10905                        [NONE]
# ...

# %% [markdown]
# Vamos a seleccionar una serie de columnas mediante intervalos, tal como se hace en excel a traves de letras como indices.

# %%
intervalo = pd.read_excel(archivo, sheet_name='emisiones_C02', usecols='A:D')
intervalo.head()
# Out:
#          País ISO 3166-1 alpha-3   Año  Total
# 0  Afganistán                AFG  1750    0.0
# 1  Afganistán                AFG  1751    0.0
# 2  Afganistán                AFG  1752    0.0
# 3  Afganistán                AFG  1753    0.0
# 4  Afganistán                AFG  1754    0.0

# %% [markdown]
# Vamos a seleccionar una serie de registros, como la vez pasada, a traves de intervalos

# %%
intervalo_2 = pd.read_excel(archivo, sheet_name='emisiones_C02', usecols='A:D', nrows=10)
intervalo_2
# Out:
#          País ISO 3166-1 alpha-3   Año  Total
# 0  Afganistán                AFG  1750      0
# 1  Afganistán                AFG  1751      0
# 2  Afganistán                AFG  1752      0
# 3  Afganistán                AFG  1753      0
# 4  Afganistán                AFG  1754      0
# 5  Afganistán                AFG  1755      0
# 6  Afganistán                AFG  1756      0
# 7  Afganistán                AFG  1757      0
# 8  Afganistán                AFG  1758      0
# 9  Afganistán                AFG  1759      0

# %% [markdown]
# ## Exportar archivo Excel

# %% [markdown]
# Vamos a exportar el df '_intervalo_' con el metodo _to_excel_.

# %%
intervalo.to_excel('CO2_percapita.xlsx', index=False)

# %%
# cargar archivo exportado
pd.read_excel('CO2_percapita.xlsx')
# Out:
#              País ISO 3166-1 alpha-3   Año         Total
# 0      Afganistán                AFG  1750  0.000000e+00
# 1      Afganistán                AFG  1751  0.000000e+00
# 2      Afganistán                AFG  1752  0.000000e+00
# 3      Afganistán                AFG  1753  0.000000e+00
# 4      Afganistán                AFG  1754  0.000000e+00
# ...           ...                ...   ...           ...
# 63099      Global                WLD  2017  3.609674e+10
# 63100      Global                WLD  2018  3.682651e+10
# 63101      Global                WLD  2019  3.708256e+10
# 63102      Global                WLD  2020  3.526409e+10
# 63103      Global                WLD  2021  3.712385e+10
#
# [63104 rows x 4 columns]

# %% [markdown]
# ## Leyendo datos de Google Sheets

# %% [markdown]
# Obtenemos el link del archivo desde Google Sheets.
#
# link: https://docs.google.com/spreadsheets/d/1P9-66nt13OmJjB-AjySSDw0YbvAZxEKZ/edit?usp=sharing&ouid=112995986981378980539&rtpof=true&sd=true
#
# Para leer el archivo, debemos ubicar el ID que inicia despues del slash de 'd' y termina en el siguiente slash.

# %%
sheet_id = '1P9-66nt13OmJjB-AjySSDw0YbvAZxEKZ'

# guardamos la url pero cambiando la extension sharing por gviz/tq?tqx=out:csv$sheet
url = f'https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet'

# %%
datos_google = pd.read_csv(url)
datos_google
# Out:
#              País ISO 3166-1 alpha-3   Año           Total          Carbón  \
# 0      Afganistán                AFG  1750               0             NaN
# 1      Afganistán                AFG  1751               0             NaN
# 2      Afganistán                AFG  1752               0             NaN
# 3      Afganistán                AFG  1753               0             NaN
# 4      Afganistán                AFG  1754               0             NaN
# ...           ...                ...   ...             ...             ...
# 63099      Global                WLD  2017  36.096.739.276  14.506.973.805
# 63100      Global                WLD  2018  36.826.506.600  14.746.830.688
# 63101      Global                WLD  2019  37.082.558.969  14.725.978.025
# 63102      Global                WLD  2020  35.264.085.734  14.174.564.010
# 63103      Global                WLD  2021  37.123.850.352  14.979.598.083
#
# ...

# %% [markdown]
# Vamos a abrir una hoja especifica del archivo en Google Sheets

# %%
sheet_id = '1P9-66nt13OmJjB-AjySSDw0YbvAZxEKZ'
sheet_name = 'emisiones_percapita'
url = f'https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet={sheet_name}'

percapita = pd.read_csv(url)
percapita.sample(5)
# Out:
#              País ISO 3166-1 alpha-3   Año      Total Carbón     Aceite  \
# 6475        Bután                BTN  1969          0    NaN        NaN
# 4884     Barbados                BRB  2010  5.329.266      0  4.841.568
# 15307  Dominicana                DMA  1825        NaN    NaN        NaN
# 49891      Serbia                SRB  1865        NaN    NaN        NaN
# 1147       Angola                AGO  1809        NaN    NaN        NaN
#
#            Gas  Cemento   Quema  Otros
# 6475       NaN      NaN     NaN    NaN
# 4884   106.701  367.659  13.338    NaN
# 15307      NaN      NaN     NaN    NaN
# 49891      NaN      NaN     NaN    NaN
# 1147       NaN      NaN     NaN    NaN

# %%
sheet_id = '1P9-66nt13OmJjB-AjySSDw0YbvAZxEKZ'
sheet_name = 'fuentes'
url = f'https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet={sheet_name}'

fuentes = pd.read_csv(url)
fuentes.sample(5)
# Out:
#                País ISO 3166-1 alpha-3   Año       Total      Carbón  \
# 27913        Jordán                JOR  1919      [NONE]      [NONE]
# 55494    Tayikistán                TJK  1756      [NONE]      [NONE]
# 28573      Kiribati                KIR  1763      [NONE]      [NONE]
# 39023  Países Bajos                NLD  1877  CDIAC 2022  CDIAC 2022
# 20933        Gambia                GMB  2011  CDIAC 2022  CDIAC 2022
#
#            Aceite         Gas        Cemento       Quema   Otros  \
# 27913      [NONE]      [NONE]         [NONE]      [NONE]  [NONE]
# 55494      [NONE]      [NONE]         [NONE]      [NONE]  [NONE]
# 28573      [NONE]      [NONE]         [NONE]      [NONE]  [NONE]
# 39023  CDIAC 2022  CDIAC 2022  Andrew cement  CDIAC 2022  [NONE]
# 20933  CDIAC 2022  CDIAC 2022  Andrew cement  CDIAC 2022  [NONE]
#
#                          Per Capita
# 27913                        [NONE]
# 55494                        [NONE]
# 28573                        [NONE]
# ...

# %% [markdown]
# ## Importar archivos JSON

# %% [markdown]
# El archivo "_pacientes.json_" no posee diccionarios anidados en los valores por lo que no presenta problemas al cargar.

# %%
import pandas as pd

# %%
# leer archivo json
df_pacientes = pd.read_json('./pacientes.json')
df_pacientes
# Out:
#      ID_paciente Enfermedad_corazon    IMC Fumador Consumo_alcohol AVC  \
# 0              0                 No  16.60      Sí              No  No
# 1              1                 No  20.34      No              No  Sí
# 2              2                 No  26.58      Sí              No  No
# 3              3                 No  24.21      No              No  No
# 4              4                 No  23.71      No              No  No
# ..           ...                ...    ...     ...             ...  ..
# 995          995                 No  28.29      Sí              No  No
# 996          996                 No  25.69      Sí              No  No
# 997          997                 Sí  26.99      No              No  No
# 998          998                 No  44.29      No              No  No
# 999          999                 No  25.83      No              No  No
#
#      Salud_fisica  Salud_mental Dificultad_caminar Sexo_biologico Rango_edad  \
# ...

# %% [markdown]
# El archivo "_pacientes_2.json_" si presenta diccionarios anidados lo que hace que la visuializacion no sea la correcta.

# %%
# leer archivo json con diccionarios anidados
df_pacientes_2 = pd.read_json('./pacientes_2.json')
df_pacientes_2
# Out:
#                                  Investigación   Año  \
# 0  Indicadores clave de enfermedades cardíacas  2020
# 1  Indicadores clave de enfermedades cardíacas  2020
# 2  Indicadores clave de enfermedades cardíacas  2020
#
#                                            Pacientes
# 0  {'ID': '01', 'Rango_edad': '55-59', 'Sexo_biol...
# 1  {'ID': '02', 'Rango_edad': '80 ó +', 'Sexo_bio...
# 2  {'ID': '03', 'Rango_edad': '65-69', 'Sexo_biol...

# %% [markdown]
# Para solucionarlo, debemos conocer la estructura del json y por tanto utilizamos el siguiente editor de json:
#
# - [JSONcrack](https://jsoncrack.com/editor)
#
# Al visualizar el archivo en este editor obtenemos un diagrama donde podemos identificar como se estructura el json
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Ahora, procedemos a normalizar el archivo json mediante el metodo _json_normalize()_ que busca expandir cada diccionario y colocar las variables en nuevas columnas. Debemos pasarle la variable que contiene el diccionario anidado

# %%
df_normalizado = pd.json_normalize(df_pacientes_2['Pacientes'])
df_normalizado
# Out:
#    ID Rango_edad Sexo_biologico    Raza    IMC Fumador Consumo_alcohol  \
# 0  01      55-59          Mujer  Blanca  16.60      Sí              No
# 1  02     80 ó +          Mujer  Blanca  20.34      No              No
# 2  03      65-69      Masculino  Blanca  26.58      Sí              No
#
#    Salud_física  Salud_mental Dificultad_caminar Actividad_física  \
# 0             3            30                 No               Sí
# 1             0             0                 No               Sí
# 2            20            30                 No               Sí
#
#   Salud_general  Horas_sueño                Problemas_salud
# 0     Muy buena            5  [Diabetes, Asma, Cancer_piel]
# 1     Muy buena            7                          [AVC]
# 2     Muy buena            8               [Diabetes, Asma]

# %% [markdown]
# ## Exportar archivo JSON

# %%
df_normalizado.to_json('historico_pacientes_norm.json')

# %%
# abrimos el archivo json
pd.read_json('historico_pacientes_norm.json')
# Out:
#    ID Rango_edad Sexo_biologico    Raza    IMC Fumador Consumo_alcohol  \
# 0   1      55-59          Mujer  Blanca  16.60      Sí              No
# 1   2     80 ó +          Mujer  Blanca  20.34      No              No
# 2   3      65-69      Masculino  Blanca  26.58      Sí              No
#
#    Salud_física  Salud_mental Dificultad_caminar Actividad_física  \
# 0             3            30                 No               Sí
# 1             0             0                 No               Sí
# 2            20            30                 No               Sí
#
#   Salud_general  Horas_sueño                Problemas_salud
# 0     Muy buena            5  [Diabetes, Asma, Cancer_piel]
# 1     Muy buena            7                          [AVC]
# 2     Muy buena            8               [Diabetes, Asma]

# %% [markdown]
# ## Importar Paginas Web

# %% [markdown]
# En los archivos, guardamos la pagina web desde donde vamos a extraer la informacion para luego importarla

# %%
import pandas as pd

# %%
df_html = pd.read_html('peliculas_wikipedia.html')
df_html
# Out:
# [                                                    0  \
#  0                                                1998
#  1                                                1999
#  2                                                2000
#  3                                                2001
#  4                                                2002
#  5                                                2003
#  6                                                2004
#  7                                                2005
#  8                                                2005
#  9                                                2006
#  10                                               2006
#  11                                               2007
#  12                                               2008
#  13  .mw-parser-output .hlist dl,.mw-parser-output ...
#
#                                                      1
#  0                                          100 Movies
# ...

# %% [markdown]
# > Nos devuelve una lista con 3 elementos, en este caso las 3 tablas que contiene la pagina.
#
# Verifiquemos el tipo de dato.

# %%
# tipo de dato
type(df_html)
# Out:
# list

# %%
# verificar cantidad de elementos
len(df_html)
# Out:
# 3

# %% [markdown]
# Seleccionamos la tabla de nuestro interes que en este caso, esta en la posicion 1.

# %%
top_peliculas = df_html[1]
top_peliculas
# Out:
#                             Film  Release year              Director  \
# 0                   Citizen Kane          1941          Orson Welles
# 1                     Casablanca          1942        Michael Curtiz
# 2                  The Godfather          1972  Francis Ford Coppola
# 3             Gone with the Wind          1939        Victor Fleming
# 4             Lawrence of Arabia          1962            David Lean
# ..                           ...           ...                   ...
# 95                 The Searchers          1956             John Ford
# 96              Bringing Up Baby          1938          Howard Hawks
# 97                    Unforgiven          1992        Clint Eastwood
# 98  Guess Who's Coming to Dinner          1967        Stanley Kramer
# 99           Yankee Doodle Dandy          1942        Michael Curtiz
#
#                       Production companies  Rank
# 0                       RKO Radio Pictures     1
# ...

# %% [markdown]
# > De esta forma llegamos a la informacion requerida en formato dataframe.
